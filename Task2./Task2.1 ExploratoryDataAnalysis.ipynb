# %% [markdown]
# ### Exploratory data Analysis - Terrorism

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Read terrorism dataset

# %%
terrorism = pd.read_csv(r"C:\\Users\\HP\\Desktop\\Internships\\Letsgrow more\\Tasks\\Tasks2\\globalterrorismdb_0718dist.csv" ,  
                        encoding="ISO-8859-1")
terrorism.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4704\2523366873.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terrorism = pd.read_csv(r"C:\\Users\\HP\\Desktop\\Internships\\Letsgrow more\\Tasks\\Tasks2\\globalterrorismdb_0718dist.csv" ,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %% [markdown]
# #### Explore Dataset

# %%
terrorism.shape
# Out:
# (181691, 135)

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terrorism.count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate      9239
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related        25038
# Length: 135, dtype: int64

# %%
terrorism.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
plt.figure(figsize = (25,7))
sns.heatmap(terrorism.isnull(),yticklabels = False)
plt.title("heatmap show the null values present in the dataframe terrorism" , fontsize = 18)
# Out:
# Text(0.5, 1.0, 'heatmap show the null values present in the dataframe terrorism')

# %%
# List of feature which have missing values
feature_with_na = [features for features in terrorism.columns if terrorism[features].isnull().sum()>1]

# print the features name and print the missing values
for feature in feature_with_na:
    print(feature , np.round(terrorism[feature].isnull().mean() , 4 ), '%missing values')
# Out:
# approxdate 0.9491 %missing values
# resolution 0.9878 %missing values
# provstate 0.0023 %missing values
# city 0.0024 %missing values
# latitude 0.0251 %missing values
# longitude 0.0251 %missing values
# specificity 0.0 %missing values
# location 0.6946 %missing values
# summary 0.364 %missing values
# alternative 0.8403 %missing values
# alternative_txt 0.8403 %missing values
# attacktype2 0.9652 %missing values
# attacktype2_txt 0.9652 %missing values
# attacktype3 0.9976 %missing values
# attacktype3_txt 0.9976 %missing values
# targsubtype1 0.0571 %missing values
# targsubtype1_txt 0.0571 %missing values
# corp1 0.2342 %missing values
# target1 0.0035 %missing values
# natlty1 0.0086 %missing values
# natlty1_txt 0.0086 %missing values
# targtype2 0.9387 %missing values
# targtype2_txt 0.9387 %missing values
# targsubtype2 0.9412 %missing values
# targsubtype2_txt 0.9412 %missing values
# corp2 0.9443 %missing values
# target2 0.9393 %missing values
# ...

# %%
terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terrorism.duplicated().sum()
# Out:
# 0

# %%
corr = terrorism.corr()
plt.figure(figsize = (18,18))
sns.heatmap(data = corr , cmap = 'prism_r')
plt.show()

# %%
plt.close()

# %% [markdown]
# #### The country with highest number of atteckes

# %%
terrorism['country_txt'].value_counts().index[0]
# Out:
# 'Iraq'

# %% [markdown]
# #### Top 10 countries with highest number of atteckes

# %%
people_died = terrorism[['country_txt' , 'nkill']].groupby('country_txt').sum()
people_died.head(10)
# Out:
#                        nkill
# country_txt
# Afghanistan          39384.0
# Albania                 42.0
# Algeria              11066.0
# Andorra                  0.0
# Angola                3043.0
# Antigua and Barbuda      0.0
# Argentina              490.0
# Armenia                 37.0
# Australia               23.0
# Austria                 30.0

# %%
people_died = terrorism[['iyear' , 'nkill']].groupby('iyear').sum()
people_died.head(10)
# Out:
#         nkill
# iyear
# 1970    174.0
# 1971    173.0
# 1972    566.0
# 1973    370.0
# 1974    539.0
# 1975    617.0
# 1976    674.0
# 1977    456.0
# 1978   1459.0
# 1979   2100.0

# %%
people_died.plot(kind = 'bar' , color = 'b' , figsize = (18,6))
plt.xlabel('Years' , fontsize = 14)
plt.ylabel('Number of people died ' , fontsize = 14)
plt.title(' Number of people died with respect to years' , fontsize = 16)
# Out:
# Text(0.5, 1.0, ' Number of people died with respect to years')

# %%
region = terrorism[['region_txt' , 'nkill']].groupby('region_txt').sum()
region
# Out:
#                                 nkill
# region_txt
# Australasia & Oceania           150.0
# Central America & Caribbean   28708.0
# Central Asia                   1000.0
# East Asia                      1152.0
# Eastern Europe                 7415.0
# Middle East & North Africa   137642.0
# North America                  4916.0
# South America                 28849.0
# South Asia                   101319.0
# Southeast Asia                15637.0
# Sub-Saharan Africa            78386.0
# Western Europe                 6694.0

# %%
region.plot(kind = 'bar' , color = 'r' , figsize = (18,6))
plt.xlabel('region', fontsize = 14)
plt.ylabel('Number of people died ' ,fontsize = 14 )
plt.title(' Number of people died with respect to region' , fontsize = 16)
# Out:
# Text(0.5, 1.0, ' Number of people died with respect to region')

# %%
attack_type = terrorism[['attacktype1_txt' , 'nkill']].groupby('attacktype1_txt').sum()
attack_type
# Out:
#                                         nkill
# attacktype1_txt
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %%
attack_type.plot(kind = 'bar' , color = 'm' , figsize = (18,6))
plt.xlabel('attack_type' , fontsize = 14)
plt.ylabel('Number of people died ' , fontsize = 14)
plt.title(' Number of people died with respect to attack_type' , fontsize = 16)
# Out:
# Text(0.5, 1.0, ' Number of people died with respect to attack_type')

# %%
weapon= terrorism[['weaptype1_txt' , 'nkill']].groupby('weaptype1_txt').sum()
weapon
# Out:
#                                                        nkill
# weaptype1_txt
# Biological                                               9.0
# Chemical                                               624.0
# Explosives                                          174277.0
# Fake Weapons                                             1.0
# Firearms                                            174894.0
# Incendiary                                            5476.0
# Melee                                                10575.0
# Other                                                  123.0
# Radiological                                             2.0
# Sabotage Equipment                                      83.0
# Unknown                                              42620.0
# Vehicle (not to include vehicle-borne explosive...    3184.0

# %%
weapon.plot(kind = 'bar' , color = 'g' , figsize = (18,6))
plt.xlabel('weapon used' , fontsize = 14)
plt.ylabel('Number of people died ' , fontsize = 14)
plt.title(' Number of people died with respect to weapon used' , fontsize = 16)
# Out:
# Text(0.5, 1.0, ' Number of people died with respect to weapon used')

# %% [markdown]
# #### Top 10 terrorist groups with most no of attacks

# %%
terrorism.gname.value_counts()[1:11]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: gname, dtype: int64

# %%
kill = terrorism.loc[:,'nkill']
print('Number of people killed by terror attack:' , int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %%
df= terrorism.pivot_table(columns = 'attacktype1_txt' , values = 'nkill' , aggfunc= 'sum')
df
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                 160297.0        24920.0           157321.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                    3642.0     3718.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                         4478.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                24231.0            880.0  32381.0

# %%
df1= terrorism.pivot_table(columns = 'country' , values = 'nkill' , aggfunc= 'sum')
df1
# Out:
# country     4     5        6     7       8     10     11    12    14    15    \
# nkill    39384.0  42.0  11066.0   0.0  3043.0   0.0  490.0  37.0  23.0  30.0
#
# country  ...  428   499   532     603    604   605   1001  1002  1003    1004
# nkill    ...  81.0   2.0   0.0  3410.0  324.0  15.0   3.0   1.0  83.0  2634.0
#
# [1 rows x 205 columns]

# %% [markdown]
# ### Summary
#
# Highest number of attacks = 2014
#
# most frequent attack type were  = Bombing/explosion
#
# Taliban  has done by highest number of attacks out of all terrorist gruop
#
# Highest number of attacks place in Iron
